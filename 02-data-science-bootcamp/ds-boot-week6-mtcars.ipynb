# %% [markdown]
# # Exercise 1
# ### using python 3.9.13

# %% [markdown]
# first I will use wget to collect the datasource

# %% [markdown]
# > wget https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv

# %% [markdown]
# let's have a look at the dataset

# %%
import pandas as pd

mtcars = pd.read_csv('mtcars.csv')
mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# not a very big dataset. lets get some more details.

# %%
# I've seen describe() used before to quickly give stats for the numerical columns. 
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# # Exercise 2
#
# find mean mpg for all cars. We can see that from the describe() function above, but be more specific here

# %%
mtcars.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
mtcars['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %% [markdown]
# ### from this, I believe we can be happy with the answer that the mean mpg is 20.090625

# %%
from numpy import average


average(mtcars['mpg'])
# Out:
# 20.090625000000003

# %% [markdown]
# # Exercise 3 - No Carbs (remove a column)
#
# I will create a new dataset for this

# %%
mtcars_noCarb = mtcars.drop(columns='carb')

mtcars_noCarb.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear'],
#       dtype='object')

# %%
mtcars_noCarb
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# # Exercise 4 - Lucky Number 8 (analyse a subset)
#
# The owner of the garage wants to do some analysis on only the cars with 8-cylinder engines.
# Create a subset data frame of these cars.

# %%
lucky8 = mtcars[mtcars['cyl'] == 8]

lucky8
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# ...

# %%
lucky8.describe()
# Out:
#              mpg   cyl        disp          hp       drat         wt  \
# count  14.000000  14.0   14.000000   14.000000  14.000000  14.000000
# mean   15.100000   8.0  353.100000  209.214286   3.229286   3.999214
# std     2.560048   0.0   67.771324   50.976886   0.372362   0.759405
# min    10.400000   8.0  275.800000  150.000000   2.760000   3.170000
# 25%    14.400000   8.0  301.750000  176.250000   3.070000   3.532500
# 50%    15.200000   8.0  350.500000  192.500000   3.115000   3.755000
# 75%    16.250000   8.0  390.000000  241.250000   3.225000   4.013750
# max    19.200000   8.0  472.000000  335.000000   4.220000   5.424000
#
#             qsec    vs         am       gear       carb
# count  14.000000  14.0  14.000000  14.000000  14.000000
# mean   16.772143   0.0   0.142857   3.285714   3.500000
# std     1.196014   0.0   0.363137   0.726273   1.556624
# min    14.500000   0.0   0.000000   3.000000   2.000000
# 25%    16.097500   0.0   0.000000   3.000000   2.250000
# ...

# %% [markdown]
# # Exercise 5 - the plot thickens
#
# Using the full data (not the subset), you want to explore the relationship between engine size and
# engine power. Produce a plot with displacement (“disp”) on the x axis and horsepower (“hp”) on the y
# axis. Use colour to illustrate the quantity of cylinders in the engine.

# %%
from plotnine import *

ggplot(data = mtcars) +geom_point(mapping = aes(x='disp', y='hp', color='cyl'))
# Out:
# <ggplot: (396848725)>
